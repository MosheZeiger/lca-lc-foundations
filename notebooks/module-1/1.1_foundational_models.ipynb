# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon isn’t a country or a government, so it has no capital. If you’re asking about a fictional setting or a future scenario, I can help brainstorm where a lunar “capital” might be located or named. Want to explore that?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 576, 'prompt_tokens': 13, 'total_tokens': 589, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DflIDVWflTRXNlS1Kn4l7bSGXmnkx', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e2b75-f5be-7050-a199-35e17e1c69c4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 576, 'total_tokens': 589, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country or a government, so it has no capital. If you’re asking about a fictional setting or a future scenario, I can help brainstorm where a lunar “capital” might be located or named. Want to explore that?

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-DflIDVWflTRXNlS1Kn4l7bSGXmnkx',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 576,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 512,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 589}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one—the Moon has no government, cities, or capital. If you’re going by wordplay, the “capital” letter of the word Moon is M.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon doesn't have a capital because it's not a country or inhabited territory. It's Earth's natural satellite with no permanent population or government.
#
# If you're asking about potential future lunar bases, there are no permanent settlements yet, though several countries and private companies are planning lunar missions and possible bases in the coming years.

# %%
model = init_chat_model(model="claude-haiku-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon doesn't have a capital because it's not a country or organized political entity. It's a natural satellite of Earth.
#
# If you're asking this as a playful question, the answer would be something like "there isn't one!" But if you're interested in lunar geography, I'd be happy to discuss lunar features, past and present space exploration there, or other moon-related topics.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun question! The Moon doesn't have a capital city, or any cities for that matter. It's a celestial body, not a country or a populated planet.
#
# However, if we were to imagine one, it would be a very interesting place! Perhaps it would be named after a famous astronomer, or a significant lunar landing site.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response)
# Out:
# content="That's a fun question! The Moon doesn't have a capital city in the way Earth does. It's a natural celestial body without any human settlements or governments.\n\nSo, the answer is: **The Moon has no capital.**" additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019e2bb0-ee0d-7122-be56-47c65ae5be56-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 10, 'output_tokens': 50, 'total_tokens': 60, 'input_token_details': {'cache_read': 0}}

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='8e8fbaa2-d6b0-437a-9b1c-c91ba4fea05b'),
#               AIMessage(content='There isn’t one. The Moon isn’t a country and has no government or capital. If you’re thinking of fiction or a game, people sometimes invent capitals with names like “Luna” or “Selene.”', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 565, 'prompt_tokens': 13, 'total_tokens': 578, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DfmKVoBTxaDCfw1Z8BLbrFA26UHj9', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e2bb2-ce29-7b92-9930-e294f4283eb5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 565, 'total_tokens': 578, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government or capital. If you’re thinking of fiction or a game, people sometimes invent capitals with names like “Luna” or “Selene.”

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='12241653-6112-4c23-8a88-23fe0475118f'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='c2d9affd-499c-4755-ab36-8a964fb24ece', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='16b075a3-81ad-4091-af26-0900bfcfb70f'),
#               AIMessage(content='Luna City is a fictional capital for a lunar polity in a sci‑fi setting. Real moon governance doesn’t exist, but here’s a fleshed-out concept you can use or adapt.\n\nQuick snapshot\n- Location: A ring of interconnected habitats on the rim of Shackleton Crater near the Moon’s south pole, with lines of sight to permanent solar energy and abundant ice deposits.\n- Government: A Moon Assembly with an elected Governor and sector councils; Earth‑Moon trade and safety oversight handled by a Lunar Council under a loose planetary federation.\n- Population: About 40,000–60,000 residents including families, scientists, engineers, service workers, and some mission personnel.\n\nKey districts and infrastructure\n- The Crescent Ring: A belt of 3D‑printed domes and tunnels forming residential neighborhoods, schools, and clinics. Each module is self-contained with life support and radiation shielding.\n- The Lumen Spire: A central tower housing solar concentrators, energy storage, and the city’s main data hub. It also serves as a cultural landmark and weather/space‑weather monitoring site.\n- Ice Archive District: Deep beneath the surface, where water ice is mined, purified, and stored. Ice is a critical resource for life support, fuel, and agriculture.\n- Gravity Gardens: Indoor agricultural domes that use hydroponics and aeroponics to produce fresh air, oxygen, and food for the city.\n- The Transit Tunnels: A network of pressurized tubes and mag‑lev pods that shuttle people and goods between districts quickly and safely.\n\nEconomy and daily life\n- Economy: Lunar water ice harvesting, helium-3 research, microgravity manufacturing, and regulated lunar tourism. Local industries include advanced 3D printing, life‑support tech, and sensor networks for space weather.\n- Daily life: A 1/6‑g environment means special equipment and training for movement, construction, and sports. Residents live on 24/7 artificial lighting cycles to simulate day and night, with quiet zones for rest. Education emphasizes engineering, geology, and planetary protection.\n- Culture: A blended community of Earth expatriates, scientists, and lunar-born residents. Festivals celebrate science, exploration, and interplanetary heritage. Language is a practical mix of English, with technical glossaries and multilingual signage.\n\nGovernance and challenges\n- Governance: The Moon Assembly drafts policy on resource use, research oversight, and safety. Local councils handle zoning, education, and healthcare. Earth authorities handle interplanetary diplomacy and large-scale procurement.\n- Challenges: Resource management (water and energy), radiation and micrometeoroid risks, supply chain dependencies with Earth, and political tensions with other lunar outposts or orbital stations. Social debates might focus on autonomy vs. federation, privacy in a highly monitored environment, and the ethics of closed‑loop life support.\n\nNotable landmarks and features\n- The Lumen Spire: Iconic solar hub and atop it, observation decks for sky watchers and tourists.\n- The Ice Archive: Glass‑walled vaults protecting centuries of lunar ice and data recorded on durable media.\n- The Gravity Theatre: A domed venue for performances that take advantage of distinctive sound and motion in low gravity.\n- The Coral Dome: A translucent biosphere full of resilient lunar plants and bioluminescent algae used for aesthetic and air purification.\n- The Surface Market: An open-air plaza where traders exchange resources, technology, and stories from Earth and beyond.\n\nStory hooks and ideas\n- A sudden power outage cripples life support, forcing residents to rely on backup systems while investigators uncover a hidden political dispute behind the outage.\n- A new ice deposit is discovered that could shift energy economics, triggering a tense race between factions inside Luna City.\n- An outpost on the far side of Shackleton claims to have found ancient radio signals, opening  ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City isn’t anywhere in our real world today—the Moon doesn’t have a capital city. But if you’re imagining a fully developed lunar civilization, Luna City can be a rich, detailed setting. Here’s a thorough, self-contained concept you can use for a story, game, or world-building project.
#
# Core concept
# - Luna City is the Moon’s administrative and cultural capital, a sprawling, self-contained metropolis built into and around a network of lava tubes and crater rims. It serves as the political heart of the Earth–Moon federation, a hub for science and industry, and a showcase for lunar culture. It blends advanced life support, autonomous robotics, and modular architecture with a distinctly lunar aesthetic: shielded domes, glassy skylights, and regolith-colored surfaces.
#
# Location and geography
# - Location: A strategically chosen equatorial zone near a major ice deposit and a broad sodium-potassium ore belt, with easy Earth comms but protected from the worst radiation by shielded shells.
# - Layout: A radial-city design built around a central governance district, with a transit spine connecting surface districts to subterranean “public chambers,” and a ring of residential and industrial sectors connected by light-rail and magnetic-levitation transit.
# - Shielding: Much of the city sits beneath regolith shielding and within lava-tube cavities to reduce radiation exposure and heat loss. Surface domes are mostly for solar farms, parks, and ceremonial spaces.
#
# Government and politics
# - polity: The lunar capital of the Earth–Moon Federation (or Crescent Commonwealth, depending on your preferred name). A bicameral Lunar Assembly handles local matters, while a Moon-Governor (with an Earth-appointed governor’s council) negotiates Earth-relations and resource deals.
# - governance style: A technocratic-democratic blend: scientists and engineers hold significant sway, but there are elected representatives from each district. AI-assisted governance helps manage resource allocation, life-support optimization, and disaster response.
# - security: A civil-military hybrid force called the Crescent Guard, focused on civilian protection, search-and-rescue, and infrastructure defense. They emphasize transparency and civilian oversight.
#
# Economy and trade
# - Sectors:
#   - Research and development: universities, lunar labs, microgravity manufacturing, materials science, life-support tech.
#   - Resource processing: water ice extraction, oxygen production, and propellants from lunar ice, plus refined metals from electrolysis and 3D-printed components.
#   - High-tech manufacturing: optics, nano-coatings, batteries, and space-grade electronics fabricated in microgravity environments.
#   - Tourism and culture: museums, lunar heritage districts, guided tours of craters and ice reservoirs, and low-gravity entertainment venues.
# - Trade: Luna City trades with Earth and with orbital facilities. Solar power beamed from the Moon to Earth and other space habitats is a potential revenue stream; rare lunar minerals and 3D-printed goods are key exports.
# - currency and finance: A lunar-based credit system tied to Earth currencies; banks run both on-world and interplanetary scales with advanced fraud protection and AI auditors.
#
# City districts and landmarks
# - The Administration District: The Parliament House, Lunar Library, the Ministry of Resource Management, and the Archives of Earth-Lunar Agreements. A grand plaza called The Lantern serves as the city’s ceremonial center.
# - The Research Quarter: Universities, labs, and test facilities for life-support tech, 3D printing, robotics, and propulsion. Often visited by visiting scientists, with honorifics and visiting fellowships.
# - The Market & Exchange District: Banks, trade floors, rations/commodity exchanges, and markets for lunar crafts and fine goods. Sculpted storefronts and holo-murals give the area a cultural flavor.
# - The Port & Logistics Hub: Surface and sub-surface docking bays, storage for ice, propellants, and spare parts, plus a shipyard for small to mid-sized lunar craft.
# - The Residential Ring: Layered living quarters in modular capsules, some rotating to simulate gravity. Parks, schools, clinics, and community centers pepper the ring.
# - The Heritage Quarter: Museums, lunar temples, theaters, and performance venues that celebrate lunar history, engineering feats, and the stories of settlers who pioneered life on the Moon.
# - The Ice Gate: A transit gateway near an ice deposit that’s fed by autonomous mining drones, water processing plants, and a research facility studying water cycles in vacuum.
# - The Lantern Dome: A high, transparent geodesic dome that acts as a civic observatory and a light-emitting landmark at night. It’s both a symbol and a practical communications hub.
#
# Technology, infrastructure, and daily life
# - life support: Closed-loop life support with hydroponic farms, algae-based oxygen generation, and water reclamation. Recycling is near 100%.
# - energy: A combination of large solar farms on the surface, shielded by domes, and compact nuclear microreactors for night-time reliability and high-demand periods.
# - climate and environment: Controlled microclimates inside each district. Outside, the vacuum and radiation are constant, so most activities happen indoors or under shielding.
# - transportation:
#   - Surface transit via mag-lev trams and autonomous lunar rovers for quick commutes.
#   - An underground rail or vacuum-tube network connects districts, with stations designed to minimize energy use.
#   - Optional rotating habitats in some sectors to simulate partial gravity for long-term health.
# - architecture: A mix of 3D-printed regolith blocks reinforced with carbon composites, inflatable modules for flexible spaces, and glass-like domes for public areas. Many surfaces are colored by dust-locked patinas that reduce glare and heat.
# - health and science: Telepresence and AI-assisted diagnostics are common. Medical bays are equipped to handle radiation exposure, bone density loss, and microgravity-related issues.
#
# society, culture, and daily life
# - demographics: A diverse mix of Earth-born settlers and people born on the Moon who have developed a distinct lunar culture—pragmatic, communal, and tech-forward.
# - language: A lingua franca blending Earth languages with lunar slang and tech jargon; sign language is widespread for operations in low-gravity or noisy workshop environments.
# - education: Strong emphasis on STEM, architecture, and environmental design. Public schools double as labs emphasizing hands-on learning with real-world lunar challenges.
# - culture: Festivals celebrate lunar cycles, Earth holidays adapted to the Moon’s day-night rhythm, and a strong tradition of “citizenship through service” in life-support and infrastructure roles.
# - arts and media: Holographic theaters, lunar cinema, and studios that record in microgravity. Museums blend interactive AR with historical exhibits.
#
# Notable people and roles
# - The Speaker of the Lunar Assembly: a high-profile political leader who must balance Earth interests with local needs.
# - Chief Engineer: oversees all life-support, energy systems, and construction projects; a celebrity among builders for innovative solutions.
# - Archivist of the Lantern: custodian of lunar history and agreements; a scholar with a keen sense for diplomacy.
# - Director of Research Quarters: leads cross-disciplinary programs in space medicine, materials science, and additive manufacturing.
# - Guardians of the Crescent: the security force, known for transparent practices and crisis-response efficiency.
#
# History and key events (quick timeline)
# - Early settlement era: Small research outposts use lava tubes for shelter, limited life-support tech, and water ice discoveries begin shaping long-term plans.
# - Founding of Luna City: A formal capital is established once a stable governance framework, reliable life support, and a central transit spine are in place.
# - The Solar Accord era: Luna City becomes a hub for Earth-Lunar trade and governance, with the Lantern Dome inaugurated as a symbol of unity.
# - Current era: Luna City expands into new districts, invests in asteroid-resource collaborations, and tightens AI-assisted governance to improve resilience.
#
# Challenges and tensions
# - Resource fairness: Ensuring water and oxygen allocations remain equitable as population grows.
# - Radiation and solar storms: High-energy events require rapid sheltering plans and robust shielding.
# - Economic disparity: Balancing high-tech innovation with the needs of a growing residential population.
# - Governance transparency: Managing AI-driven decision-making to keep human oversight meaningful.
# - Environmental ethics: Debates about mining, surface contamination, and preservation of lunar sites.
#
# Story seeds and hooks (if you’re writing fiction)
# - A political scandal erupts when an AI advisor predicts a resource shortage unless a controversial new mining regime is approved.
# - A water-ice theft disrupts life support in a district, triggering a city-wide manhunt and a race to identify insiders involved.
# - An expedition to a nearby crater reveals ancient lunar artifacts that challenge the Moon’s official history.
# - A solar storm destroys weeks of data logs; investigators uncover a covert plan to manipulate the lunar stockpile.
# - A cultural festival is sabotaged, sparking a diplomatic crisis between lunar factions and Earth authorities.
#
# If you want, I can tailor this concept to a specific genre (hard sci-fi realism, space opera, cyberpunk, etc.), set a detailed map of districts, write a one-page world bible, or adapt Luna City for a game campaign. Tell me your preferred tone, era (near-future, mid-century, far-future), and any key themes you want to emphasize.
