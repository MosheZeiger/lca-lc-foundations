# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# Capital: Lunopolis
#
# In this setting, Lunopolis is the political heart of the Moon. It sits on the southern polar rim of Shackleton Crater, tucked inside a cluster of interconnected domes shielded from radiation and micrometeoroids. Light is harvested from a lattice of sun-tracking heliostats, and water ice mined from the crater walls feeds a network of life-supported gardens.
#
# Key features:
# - Government: The Lunarian Council sits in the Crescent Dome, the seat of power. The city also hosts the Parliament of Four, a tribunal system representing science, industry, agriculture, and culture.
# - Districts:
#   - Crescent Dome: the capitol complex and grand hall where laws are made.
#   - Glass Sea District: solar farms and high-precision glass fabrication.
#   - Iron Spine: manufacturing, habitat rings, and lunar mining logistics.
#   - Archive Quarter: the lunar library and data vaults preserving lunar heritage and scientific records.
# - Architecture: transparent and basalt-infused megastructures, with gravity-assisted parks and vertical farming that float gently in low gravity.
# - Culture and daily life: a blend of grit and elegance; art and performance exploit the low gravity to create sweeping choreographies; citizens travel via gravity-tethered tubes and elevator shafts between domes.
#
# If you’d like, I can tailor Lunopolis to a specific era, politics, or culture within your broader Moon-world.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'moon_city.png', 'type': 'image/png', 'size': 7807892, 'content': <memory at 0x7ed960b20640>, 'last_modified': datetime.datetime(2026, 5, 15, 16, 3, 17, 810000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# Here’s a portrait of the capital you’re looking at—Aurora City, the beating heart of Titan Colony Alpha.
#
# Overview
# - Aurora City sits in a flattened crater rim on Titan, where engineers wrestled the moon’s frigid reality into a habitable, thriving metropolis. The orange haze of Titan’s atmosphere glows through vast glass domes and reflective coatings, giving the city a perpetual sunset feel.
# - It’s the political, cultural, and scientific nerve center of the colony. The government, research institutes, bold industrial complexes, and the culture quarter cluster around a monumental central hub known as The Crown.
#
# Cityscape and districts
# - The Crown Dome: A towering, transparent sphere that houses the seat of government, grand archives, and public squares. Inside, climate-controlled gardens, public data walls, and a living archive of Titan’s exploration history keep the city’s memory luminous.
# - Agripacific Arcology: A ring of interconnected domes and towers dedicated to food production, hydroponics, and bioluminescent farms. Titan’s agriculture is engineered to thrive in methane-rich air, with vertical farms weaving between habitat blocks.
# - The Aegis Industrial Belt: A choreography of factories, power stations, and maintenance yards. Modular factories shuttle between cores on magnetic rails, keeping Titan’s energy, materials, and spare parts flowing.
# - The Gate and Viewpoints: A pair of observation decks and sculpture terraces perched above the crater rim. The Titan Viewpoint sign marks the safest overlook where the orange sky makes the rings of Saturn look within reach.
# - Cultural Quarter: Theaters, holographic galleries, and a concert hall that doubles as a large data-museum. Public art is powered by algae-assisted bioluminescence, turning night into a gentle aurora.
# - Residential Arches: Low-gravity neighborhoods built in stepped arcs with warm corridors, social hubs, and communal hydroponic balconies. Inside, the air is circulated, filtered, and conditioned to a constant comfort.
#
# Technology and daily life
# - Climate control and life support: The domes pressurize Titan’s air and maintain a comfortable climate (roughly room temperature) inside, while outside the suits and habitat shells protect residents from the world’s cryogenic temperatures and hydrocarbon-rich atmosphere.
# - Energy: A hybrid system of compact nuclear micro-reactors, solar mirrors, and methane-processing plants powers the city. Waste heat is reclaimed to warm streets and promenades.
# - Transportation: A network of hover-trams and magnetic rails crisscross the crater floor. People move on pressurized walkways, and small rovers ferry goods between arcologies. Gravity is lower here, so travel feels buoyant but careful—falls are gentle and slow.
# - Architecture: Transparent domes connect with basalt and glass, using reflective coatings to modulate heat. Inside, modular rooms adapt to family size and work needs; exterior terraces double as solar gardens or rainwater catchments (even in Titan’s atmosphere, water is a precious resource).
#
# Society and governance
# - Government: A Council of Scribes and Synths—humans, AI-assisted systems, and autonomous agents—work together in an open governance model. Public policy proposals flow from citizen assemblies, refined by predictive simulators, and enacted by the Council in quarterly sessions.
# - Economy: Titan’s hydrocarbons and cryogenic work fuel industry and research. Advanced biotechnologies make living solutions—air, soil, food, and medicine—more efficient. Aurora City trades with other colonies via orbital stations and surface convoys.
# - Culture: Life on Titan embraces a shared ethos of resilience, curiosity, and beauty. Festivals celebrate the changing methane skies, the rings’ reflections, and new breakthroughs in cryogenics and hydroponics. Music often blends synthetic instruments with real-time data sonifications.
# - Education and research: The Academy of Titan Studies sits near the Crown, focused on planetary science, astroengineering, and xenobiology in extreme environments. Student researcher programs bring new minds into the field, young engineers into the labs, and old hands into mentorship.
#
# Landmarks and atmosphere
# - The Helios Gate: A shimmering entrance to the governance district, powered by sky-bridges and light sculptures that respond to public mood and weather data.
# - Saturn Gate Viewpoint: A platform that frames Saturn’s rings with holographic guides, letting visitors “step into” space history without leaving Titan’s surface.
# - The Echo Amphitheatre: An outdoor venue where acoustics are tuned by ambient methane currents, producing a natural reverb that makes performances feel otherworldly.
#
# Challenges and story seeds
# - Resource balance: Titan’s supply chains depend on careful methane processing, energy recycling, and water recovery. Any disruption tests Aurora City’s resilience.
# - Social cohesion: A diverse mix of scientists, workers, and explorers create vibrant culture but require ongoing dialogue to prevent rifts between districts.
# - Environmental risks: Methane hazes and occasional solar storms can affect visibility and life-support systems, prompting maintenance and rapid-response drills.
# - Frontier dreams: The city serves as a launchpad for deeper Titan exploration, with missions to cryovolcanoes, methane seas, and subsurface oceans.
#
# If you’d like, I can map out a specific district, draft a day-in-the-life vignette set in Aurora City, or design a short political scene in The Crown. Would you prefer a tighter location focus (e.g., The Crown and Agripacific arc) or a broader tour of the whole capital?

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# ---------------------------------------------------------------------------
# PortAudioError                            Traceback (most recent call last)
# Cell In[9], line 13
#      10 sample_rate = 44100
#      12 print("Recording...")
# ---> 13 audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
#      14 # Progress bar for the duration
#      15 for _ in tqdm(range(duration * 10)):   # update 10× per second
#
# File ~/projects/lca-lc-foundations/.venv/lib/python3.12/site-packages/sounddevice.py:284, in rec(frames, samplerate, channels, dtype, out, mapping, blocking, **kwargs)
#     281     ctx.read_indata(indata)
#     282     ctx.callback_exit()
# --> 284 ctx.start_stream(InputStream, samplerate, ctx.input_channels,
#     285                  ctx.input_dtype, callback, blocking, **kwargs)
#     286 return out
#
# File ~/projects/lca-lc-foundations/.venv/lib/python3.12/site-packages/sounddevice.py:2664, in _CallbackContext.start_stream(self, StreamClass, samplerate, channels, dtype, callback, blocking, **kwargs)
#    2661 def start_stream(self, StreamClass, samplerate, channels, dtype, callback,
#    2662                  blocking, **kwargs):
#    2663     stop()  # Stop previous playback/recording
# -> 2664     self.stream = StreamClass(samplerate=samplerate,
#    2665                               channels=channels,
#    2666                               dtype=dtype,
#    2667                               callback=callback,
#    2668                               finished_callback=self.finished_callback,
#    2669                               **kwargs)
#    2670     self.stream.start()
#    2671     global _last_callback
#
# File ~/projects/lca-lc-foundations/.venv/lib/python3.12/site-packages/sounddevice.py:1457, in InputStream.__init__(self, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback)
#    1425 def __init__(self, samplerate=None, blocksize=None,
#    1426              device=None, channels=None, dtype=None, latency=None,
#    1427              extra_settings=None, callback=None, finished_callback=None,
#    1428              clip_off=None, dither_off=None, never_drop_input=None,
#    1429              prime_output_buffers_using_stream_callback=None):
#    1430     """PortAudio input stream (using NumPy).
#    1431
#    1432     This has the same methods and attributes as `Stream`, except
#    (...)   1455
#    1456     """
# -> 1457     _StreamBase.__init__(self, kind='input', wrap_callback='array',
#    1458                          **_remove_self(locals()))
#
# File ~/projects/lca-lc-foundations/.venv/lib/python3.12/site-packages/sounddevice.py:833, in _StreamBase.__init__(self, kind, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback, userdata, wrap_callback)
#     830         samplerate = isamplerate
#     831 else:
#     832     parameters, self._dtype, self._samplesize, samplerate = \
# --> 833         _get_stream_parameters(kind, device, channels, dtype, latency,
#     834                                extra_settings, samplerate)
#     835     self._device = parameters.device
#     836     self._channels = parameters.channelCount
#
# File ~/projects/lca-lc-foundations/.venv/lib/python3.12/site-packages/sounddevice.py:2750, in _get_stream_parameters(kind, device, channels, dtype, latency, extra_settings, samplerate)
#    2747 if samplerate is None:
#    2748     samplerate = default.samplerate
# -> 2750 info = query_devices(device)
#    2751 if channels is None:
#    2752     channels = info['max_' + kind + '_channels']
#
# File ~/projects/lca-lc-foundations/.venv/lib/python3.12/site-packages/sounddevice.py:577, in query_devices(device, kind)
#     575 info = _lib.Pa_GetDeviceInfo(device)
#     576 if not info:
# --> 577     raise PortAudioError(f'Error querying device {device}')
#     578 assert info.structVersion == 2
#     579 name_bytes = _ffi_string(info.name)
#
# PortAudioError: Error querying device -1

# %%
agent = create_agent(
    model='gpt-4o-audio-preview',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
